# %%
# 导入库
import pandas as pd
import numpy as np
import tushare as ts
import statsmodels as sm
from pandas.core.frame import DataFrame
from pandas import Series
import time
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# 连接数据库
engine = create_engine('mysql://root:K@ppy213@localhost/sjfx?charset=utf8')
# 获取当前日期，并格式化为字符串
today_date=time.strftime("%Y%m%d")

# %% [markdown]
# #### 获取当日全部股票数据

# %%
# 获取当日全部股票数据
all_data=ts.get_today_all()
all_data
# 写到本地Excel
# all_data.to_excel('D:/TuShare/'+today_date+'_Today_All.xlsx')
# 写到本地CSV
# all_data.to_csv('D:/TuShare/'+today_date+'_Today_All.csv')
# # 写入到数据库
# all_data.to_sql(today_date+'_all',engine,if_exists='append')
# Out:
# [Getting data:]############################################################
#         code   name  changepercent   trade    open    high     low  \
# 0     688388   嘉元科技         -0.387   56.69   56.90   57.20   56.28
# 1     688333    铂力特          0.390   77.30   74.63   78.50   73.36
# 2     688321   微芯生物         -0.700   68.05   69.53   69.54   67.88
# 3     688188   柏楚电子         -0.212  150.94  150.50  151.85  149.57
# 4     688168    安博通          0.655  141.39  140.00  144.76  139.21
# 5     688122   西部超导         -0.747   46.51   46.61   46.98   46.22
# 6     688099   晶晨股份         -0.708   84.20   85.00   85.30   83.50
# 7     688088   虹软科技         -0.500   63.70   64.98   64.98   63.55
# 8     688066   航天宏图          0.000   56.80   56.60   57.60   55.89
# 9     688033   天宜上佳          1.809   39.96   39.88   41.05   39.55
# 10    688029   南微医学         -0.133  134.88  134.34  136.00  133.85
# 11    688028    沃尔德          0.241  116.50  114.60  118.78  113.01
# ...

# %% [markdown]
# #### 获取所有目标个股的全部历史数据

# %%
# 获取个股当日前全部历史数据
hsdz='600570'
all_hsdz=ts.get_hist_data(hsdz)
all_hsdz.to_sql(today_date+'_hsdz',engine,if_exists='append')

# %% [markdown]
# #### 代码测试

# %%
# 测试
gp_list=['600570','300377','300085','300348']
for gp in gp_list:
    ts.get_hist_data(gp)
#     print(gp)
#     time.sleep(2)

# %%
# 高级查询
datas.loc[datas.loc[:,'changepercent'] > 9]
# Out:
#         code   name  changepercent  trade   open   high    low  settlement  \
# 30    603998   方盛制药         10.000   8.47   7.70   8.47   7.58        7.70
# 54    603963   大理药业          9.509  14.28  13.19  14.34  13.09       13.04
# 67    603927    中科软         10.000  25.63  25.63  25.63  25.63       23.30
# 205   603662   柯力传感          9.996  53.04  52.18  53.04  51.50       48.22
# 339   603322   超讯通信         10.013  25.82  25.82  25.82  25.82       23.47
# 378   603232   格尔软件         10.000  35.97  33.09  35.97  32.25       32.70
# 447   603093   南华期货         10.040  13.59  13.59  13.59  13.59       12.35
# 501   603011   合锻智能          9.985   7.16   6.22   7.16   5.88        6.51
# 507   603005   晶方科技         10.022  24.48  22.30  24.48  22.30       22.25
# 605   601519    大智慧          9.989  10.13   9.08  10.13   9.00        9.21
# 1324  600225   天津松江          9.913   3.77   3.67   3.77   3.67        3.43
# ...

# %%
list=['恒生电子','金证股份','长亮科技']
for i in range(0,3):
    print(list[i])
# Out:
# 恒生电子
# 金证股份
# 长亮科技

# %%
datas.loc[datas.loc[:,'name']=='恒生电子']
# Out:
#         code  name  changepercent  trade   open  high    low  settlement  \
# 1050  600570  恒生电子         -1.517  83.09  84.85  85.3  82.12       84.37
#
#           volume  turnoverratio        amount     per      pb        mktcap  \
# 1050  24301874.0        3.02583  2.030654e+09  79.894  18.114  6.673346e+06
#
#                nmc
# 1050  6.673346e+06
